# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | krasnoye
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | talnakh
# Processing Record 11 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 1 | cuamba
# Processing Record 13 of Set 1 | ponta do sol
# Processing Record 14 of Set 1 | pacific grove
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | port hardy
# Processing Record 17 of Set 1 | coihaique
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | kutum
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | sorsk
# Processing Record 26 of Set 1 | nouadhibou
# Processing Record 27 of Set 1 | itapage
# Processing Record 28 of Set 1 | aloleng
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | rio gallegos
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | murgab
# Processing Record 38 of Set 1 | kaputa
# Processing Record 39 of Set 1 | sao filipe
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | areka
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | fare
# Processing Record 45 of Set 1 | yulara
# Processing Record 46 of Set 1 | anadyr
# Processing Record 47 of Set 1 | maindargi
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | leningradskiy
# Processing Record 3 of Set 2 | balkanabat
# Processing Record 4 of Set 2 | sinnar
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 2 | salobrena
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | kudahuvadhoo
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | guerrero negro
# Processing Record 14 of Set 2 | naze
# Processing Record 15 of Set 2 | severo-kurilsk
# Processing Record 16 of Set 2 | talara
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | lavrentiya
# Processing Record 19 of Set 2 | san cristobal
# Processing Record 20 of Set 2 | evensk
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | ayr
# Processing Record 23 of Set 2 | lagoa
# Processing Record 24 of Set 2 | moussoro
# Processing Record 25 of Set 2 | bograd
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | baruun-urt
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | pevek
# Processing Record 30 of Set 2 | cidreira
# Processing Record 31 of Set 2 | taoudenni
# Processing Record 32 of Set 2 | koungou
# Processing Record 33 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 2 | andrews
# Processing Record 35 of Set 2 | vaini
# Processing Record 36 of Set 2 | chuy
# Processing Record 37 of Set 2 | padang
# Processing Record 38 of Set 2 | saint george
# Processing Record 39 of Set 2 | salalah
# Processing Record 40 of Set 2 | bose
# Processing Record 41 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | matay
# Processing Record 44 of Set 2 | payo
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 47 of Set 2 | bredasdorp
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | juba
# Processing Record 50 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 3 | la ronge
# Processing Record 2 of Set 3 | sioux lookout
# Processing Record 3 of Set 3 | quatre cocos
# Processing Record 4 of Set 3 | beringovskiy
# Processing Record 5 of Set 3 | dalgopol
# Processing Record 6 of Set 3 | korla
# Processing Record 7 of Set 3 | senekal
# Processing Record 8 of Set 3 | xining
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | bayburt
# Processing Record 11 of Set 3 | pisco
# Processing Record 12 of Set 3 | bahia honda
# Processing Record 13 of Set 3 | tual
# Processing Record 14 of Set 3 | isla mujeres
# Processing Record 15 of Set 3 | kampene
# Processing Record 16 of Set 3 | henzada
# City not found. Skipping...
# Processing Record 17 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 3 | atambua
# Processing Record 19 of Set 3 | morro bay
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | klaksvik
# Processing Record 22 of Set 3 | sao joao da barra
# Processing Record 23 of Set 3 | sur
# Processing Record 24 of Set 3 | hrodna
# Processing Record 25 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 3 | alekseyevsk
# Processing Record 27 of Set 3 | cabo san lucas
# Processing Record 28 of Set 3 | saint-louis
# Processing Record 29 of Set 3 | arman
# Processing Record 30 of Set 3 | kavaratti
# Processing Record 31 of Set 3 | tahta
# Processing Record 32 of Set 3 | saint-philippe
# Processing Record 33 of Set 3 | tabou
# Processing Record 34 of Set 3 | chandbali
# Processing Record 35 of Set 3 | grand gaube
# Processing Record 36 of Set 3 | mount isa
# Processing Record 37 of Set 3 | chokurdakh
# Processing Record 38 of Set 3 | souillac
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | dicabisagan
# Processing Record 42 of Set 3 | sitka
# Processing Record 43 of Set 3 | alofi
# Processing Record 44 of Set 3 | abu kamal
# Processing Record 45 of Set 3 | aksu
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | kruisfontein
# Processing Record 48 of Set 3 | smithers
# Processing Record 49 of Set 3 | college
# Processing Record 50 of Set 3 | mehamn
# Processing Record 1 of Set 4 | shimoda
# Processing Record 2 of Set 4 | shellbrook
# Processing Record 3 of Set 4 | iqaluit
# Processing Record 4 of Set 4 | san francisco
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | georgetown
# Processing Record 7 of Set 4 | mangai
# Processing Record 8 of Set 4 | qrendi
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | faanui
# Processing Record 11 of Set 4 | gizo
# Processing Record 12 of Set 4 | hay river
# Processing Record 13 of Set 4 | broome
# Processing Record 14 of Set 4 | mahebourg
# Processing Record 15 of Set 4 | avarua
# Processing Record 16 of Set 4 | cape elizabeth
# City not found. Skipping...
# Processing Record 17 of Set 4 | campo maior
# Processing Record 18 of Set 4 | vila franca do campo
# Processing Record 19 of Set 4 | mar del plata
# Processing Record 20 of Set 4 | kloulklubed
# Processing Record 21 of Set 4 | barreirinhas
# Processing Record 22 of Set 4 | dongsheng
# Processing Record 23 of Set 4 | berlevag
# Processing Record 24 of Set 4 | quelimane
# Processing Record 25 of Set 4 | zihuatanejo
# Processing Record 26 of Set 4 | lar
# Processing Record 27 of Set 4 | corinto
# Processing Record 28 of Set 4 | gijon
# Processing Record 29 of Set 4 | ucluelet
# Processing Record 30 of Set 4 | makakilo city
# Processing Record 31 of Set 4 | turayf
# Processing Record 32 of Set 4 | ancud
# Processing Record 33 of Set 4 | petropavl
# Processing Record 34 of Set 4 | pangnirtung
# Processing Record 35 of Set 4 | calamar
# Processing Record 36 of Set 4 | najran
# Processing Record 37 of Set 4 | rio grande
# Processing Record 38 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 4 | comodoro rivadavia
# Processing Record 40 of Set 4 | vincennes
# Processing Record 41 of Set 4 | port-cartier
# Processing Record 42 of Set 4 | gorom-gorom
# Processing Record 43 of Set 4 | ostrovnoy
# Processing Record 44 of Set 4 | sydney
# Processing Record 45 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 4 | kosonsoy
# Processing Record 47 of Set 4 | acu
# Processing Record 48 of Set 4 | maniitsoq
# Processing Record 49 of Set 4 | barcani
# Processing Record 50 of Set 4 | doha
# Processing Record 1 of Set 5 | osa
# Processing Record 2 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 5 | kushmurun
# Processing Record 4 of Set 5 | porto velho
# Processing Record 5 of Set 5 | mount gambier
# Processing Record 6 of Set 5 | lompoc
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 5 | cockburn town
# Processing Record 10 of Set 5 | nome
# Processing Record 11 of Set 5 | jega
# Processing Record 12 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 5 | obihiro
# Processing Record 14 of Set 5 | upata
# Processing Record 15 of Set 5 | baykit
# Processing Record 16 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 5 | kotido
# Processing Record 18 of Set 5 | port hedland
# Processing Record 19 of Set 5 | kinna
# Processing Record 20 of Set 5 | shingu
# Processing Record 21 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 5 | saint-francois
# Processing Record 23 of Set 5 | mayskiy
# Processing Record 24 of Set 5 | coahuayana
# Processing Record 25 of Set 5 | port-gentil
# Processing Record 26 of Set 5 | kailua
# Processing Record 27 of Set 5 | kavieng
# Processing Record 28 of Set 5 | qaqortoq
# Processing Record 29 of Set 5 | kendari
# Processing Record 30 of Set 5 | shushtar
# Processing Record 31 of Set 5 | bambanglipuro
# Processing Record 32 of Set 5 | nuuk
# Processing Record 33 of Set 5 | lumphat
# Processing Record 34 of Set 5 | nanortalik
# Processing Record 35 of Set 5 | saskylakh
# Processing Record 36 of Set 5 | yar-sale
# Processing Record 37 of Set 5 | antofagasta
# Processing Record 38 of Set 5 | kysyl-syr
# Processing Record 39 of Set 5 | east london
# Processing Record 40 of Set 5 | hasan abdal
# Processing Record 41 of Set 5 | bonham
# Processing Record 42 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 5 | raga
# Processing Record 44 of Set 5 | bonthe
# Processing Record 45 of Set 5 | cherskiy
# Processing Record 46 of Set 5 | kifri
# Processing Record 47 of Set 5 | hirara
# Processing Record 48 of Set 5 | durban
# Processing Record 49 of Set 5 | nuevo progreso
# Processing Record 50 of Set 5 | katsuura
# Processing Record 1 of Set 6 | santa rosa
# Processing Record 2 of Set 6 | japura
# Processing Record 3 of Set 6 | marataizes
# Processing Record 4 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 6 | port elizabeth
# Processing Record 6 of Set 6 | olafsvik
# Processing Record 7 of Set 6 | hambantota
# Processing Record 8 of Set 6 | aleksandrovskiy zavod
# Processing Record 9 of Set 6 | vila
# Processing Record 10 of Set 6 | gunnedah
# Processing Record 11 of Set 6 | gurskoye
# City not found. Skipping...
# Processing Record 12 of Set 6 | mnogovershinnyy
# Processing Record 13 of Set 6 | nantucket
# Processing Record 14 of Set 6 | akdepe
# Processing Record 15 of Set 6 | baykalsk
# Processing Record 16 of Set 6 | ziro
# Processing Record 17 of Set 6 | dubbo
# Processing Record 18 of Set 6 | kangasala
# Processing Record 19 of Set 6 | kiruna
# Processing Record 20 of Set 6 | eenhana
# Processing Record 21 of Set 6 | bairiki
# Processing Record 22 of Set 6 | mayor pablo lagerenza
# Processing Record 23 of Set 6 | keningau
# Processing Record 24 of Set 6 | yumen
# Processing Record 25 of Set 6 | vila velha
# Processing Record 26 of Set 6 | hamilton
# Processing Record 27 of Set 6 | hasaki
# Processing Record 28 of Set 6 | lorengau
# Processing Record 29 of Set 6 | geraldton
# Processing Record 30 of Set 6 | provideniya
# Processing Record 31 of Set 6 | taraz
# Processing Record 32 of Set 6 | bilibino
# Processing Record 33 of Set 6 | newport
# Processing Record 34 of Set 6 | luwuk
# Processing Record 35 of Set 6 | clacton-on-sea
# Processing Record 36 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 6 | severobaykalsk
# Processing Record 38 of Set 6 | sorland
# Processing Record 39 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 40 of Set 6 | husavik
# Processing Record 41 of Set 6 | isangel
# Processing Record 42 of Set 6 | raudeberg
# Processing Record 43 of Set 6 | kamen-rybolov
# Processing Record 44 of Set 6 | khash
# Processing Record 45 of Set 6 | haapiti
# Processing Record 46 of Set 6 | komsomolskiy
# Processing Record 47 of Set 6 | upernavik
# Processing Record 48 of Set 6 | tura
# Processing Record 49 of Set 6 | ossora
# Processing Record 50 of Set 6 | qui nhon
# Processing Record 1 of Set 7 | ewa beach
# Processing Record 2 of Set 7 | ballina
# Processing Record 3 of Set 7 | esperance
# Processing Record 4 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 7 | marquette
# Processing Record 6 of Set 7 | yertsevo
# Processing Record 7 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 7 | aykhal
# Processing Record 9 of Set 7 | port lincoln
# Processing Record 10 of Set 7 | san jose
# Processing Record 11 of Set 7 | fortuna
# Processing Record 12 of Set 7 | novita
# Processing Record 13 of Set 7 | san patricio
# Processing Record 14 of Set 7 | karaton
# Processing Record 15 of Set 7 | kidodi
# Processing Record 16 of Set 7 | barcelos
# Processing Record 17 of Set 7 | vorobyevka
# Processing Record 18 of Set 7 | bandarbeyla
# Processing Record 19 of Set 7 | kolvereid
# Processing Record 20 of Set 7 | tiznit
# Processing Record 21 of Set 7 | oranjemund
# Processing Record 22 of Set 7 | inongo
# Processing Record 23 of Set 7 | colac
# Processing Record 24 of Set 7 | araouane
# Processing Record 25 of Set 7 | vostochnyy
# Processing Record 26 of Set 7 | payson
# Processing Record 27 of Set 7 | nyandoma
# Processing Record 28 of Set 7 | santa barbara
# Processing Record 29 of Set 7 | altay
# Processing Record 30 of Set 7 | sisimiut
# Processing Record 31 of Set 7 | jiuquan
# Processing Record 32 of Set 7 | constitucion
# Processing Record 33 of Set 7 | tarbagatay
# Processing Record 34 of Set 7 | tandalti
# Processing Record 35 of Set 7 | xiangxiang
# Processing Record 36 of Set 7 | kirakira
# Processing Record 37 of Set 7 | tiksi
# Processing Record 38 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 7 | tautira
# Processing Record 40 of Set 7 | tucupita
# Processing Record 41 of Set 7 | anloga
# Processing Record 42 of Set 7 | ugep
# Processing Record 43 of Set 7 | vardo
# Processing Record 44 of Set 7 | los llanos de aridane
# Processing Record 45 of Set 7 | reading
# Processing Record 46 of Set 7 | sept-iles
# Processing Record 47 of Set 7 | lavras
# Processing Record 48 of Set 7 | qingdao
# Processing Record 49 of Set 7 | tokur
# Processing Record 50 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 8 | buraydah
# Processing Record 2 of Set 8 | kuala terengganu
# Processing Record 3 of Set 8 | ponta delgada
# Processing Record 4 of Set 8 | witrivier
# City not found. Skipping...
# Processing Record 5 of Set 8 | barkot
# Processing Record 6 of Set 8 | miri
# Processing Record 7 of Set 8 | luderitz
# Processing Record 8 of Set 8 | santa maria del oro
# Processing Record 9 of Set 8 | hofn
# Processing Record 10 of Set 8 | pasaje
# Processing Record 11 of Set 8 | koutsouras
# Processing Record 12 of Set 8 | morant bay
# Processing Record 13 of Set 8 | flinders
# Processing Record 14 of Set 8 | bardiyah
# Processing Record 15 of Set 8 | bud
# Processing Record 16 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 8 | nosy varika
# Processing Record 18 of Set 8 | havoysund
# Processing Record 19 of Set 8 | okhotsk
# Processing Record 20 of Set 8 | roald
# Processing Record 21 of Set 8 | torres
# Processing Record 22 of Set 8 | xudat
# Processing Record 23 of Set 8 | kungsbacka
# Processing Record 24 of Set 8 | solnechnyy
# Processing Record 25 of Set 8 | te anau
# Processing Record 26 of Set 8 | lebu
# Processing Record 27 of Set 8 | galesong
# Processing Record 28 of Set 8 | ovre ardal
# Processing Record 29 of Set 8 | saint-leu
# Processing Record 30 of Set 8 | rawson
# Processing Record 31 of Set 8 | orocue
# Processing Record 32 of Set 8 | dingle
# Processing Record 33 of Set 8 | colon
# Processing Record 34 of Set 8 | daman
# Processing Record 35 of Set 8 | chambersburg
# Processing Record 36 of Set 8 | tailai
# Processing Record 37 of Set 8 | sicuani
# Processing Record 38 of Set 8 | mujiayingzi
# Processing Record 39 of Set 8 | teya
# Processing Record 40 of Set 8 | asyut
# Processing Record 41 of Set 8 | farmington
# Processing Record 42 of Set 8 | shache
# Processing Record 43 of Set 8 | ahipara
# Processing Record 44 of Set 8 | ryotsu
# Processing Record 45 of Set 8 | qena
# Processing Record 46 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 8 | puerto escondido
# Processing Record 48 of Set 8 | udachnyy
# Processing Record 49 of Set 8 | ixtapa
# Processing Record 50 of Set 8 | nava
# Processing Record 1 of Set 9 | nagua
# Processing Record 2 of Set 9 | barra patuca
# Processing Record 3 of Set 9 | kondinskoye
# Processing Record 4 of Set 9 | deputatskiy
# Processing Record 5 of Set 9 | weligama
# Processing Record 6 of Set 9 | rottenburg
# Processing Record 7 of Set 9 | grootfontein
# Processing Record 8 of Set 9 | half moon bay
# Processing Record 9 of Set 9 | carutapera
# Processing Record 10 of Set 9 | tema
# Processing Record 11 of Set 9 | manavalakurichi
# Processing Record 12 of Set 9 | portland
# Processing Record 13 of Set 9 | vestmanna
# Processing Record 14 of Set 9 | gigmoto
# Processing Record 15 of Set 9 | cururupu
# Processing Record 16 of Set 9 | biak
# Processing Record 17 of Set 9 | ola
# Processing Record 18 of Set 9 | ningxiang
# Processing Record 19 of Set 9 | vostok
# Processing Record 20 of Set 9 | manggar
# Processing Record 21 of Set 9 | mildura
# Processing Record 22 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 9 | clyde river
# Processing Record 24 of Set 9 | mattru
# Processing Record 25 of Set 9 | kibala
# Processing Record 26 of Set 9 | pulandian
# Processing Record 27 of Set 9 | ulladulla
# Processing Record 28 of Set 9 | gutierrez
# Processing Record 29 of Set 9 | tuysarkan
# City not found. Skipping...
# Processing Record 30 of Set 9 | namatanai
# Processing Record 31 of Set 9 | champerico
# Processing Record 32 of Set 9 | simoes
# Processing Record 33 of Set 9 | atar
# Processing Record 34 of Set 9 | deblin
# Processing Record 35 of Set 9 | myaundzha
# Processing Record 36 of Set 9 | bundaberg
# Processing Record 37 of Set 9 | tibiri
# Processing Record 38 of Set 9 | olenino
# Processing Record 39 of Set 9 | aswan
# Processing Record 40 of Set 9 | riyadh
# Processing Record 41 of Set 9 | addanki
# Processing Record 42 of Set 9 | longyearbyen
# Processing Record 43 of Set 9 | san quintin
# Processing Record 44 of Set 9 | svetlyy
# Processing Record 45 of Set 9 | bridlington
# Processing Record 46 of Set 9 | ust-ishim
# Processing Record 47 of Set 9 | kautokeino
# Processing Record 48 of Set 9 | touros
# Processing Record 49 of Set 9 | karachi
# Processing Record 50 of Set 9 | mata
# Processing Record 1 of Set 10 | hovd
# Processing Record 2 of Set 10 | dunedin
# Processing Record 3 of Set 10 | luganville
# Processing Record 4 of Set 10 | laguna de perlas
# Processing Record 5 of Set 10 | acapulco
# Processing Record 6 of Set 10 | kapuskasing
# Processing Record 7 of Set 10 | kaitangata
# Processing Record 8 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 10 | fairbanks
# Processing Record 10 of Set 10 | mumbwa
# Processing Record 11 of Set 10 | bowen
# Processing Record 12 of Set 10 | tuatapere
# Processing Record 13 of Set 10 | vilhena
# Processing Record 14 of Set 10 | zharkovskiy
# Processing Record 15 of Set 10 | san ignacio
# Processing Record 16 of Set 10 | namibe
# Processing Record 17 of Set 10 | canby
# Processing Record 18 of Set 10 | havre-saint-pierre
# Processing Record 19 of Set 10 | maragogi
# Processing Record 20 of Set 10 | jumla
# Processing Record 21 of Set 10 | arroyo
# Processing Record 22 of Set 10 | tezu
# Processing Record 23 of Set 10 | honningsvag
# Processing Record 24 of Set 10 | vanimo
# Processing Record 25 of Set 10 | shush
# Processing Record 26 of Set 10 | itarema
# Processing Record 27 of Set 10 | la asuncion
# Processing Record 28 of Set 10 | la palma
# Processing Record 29 of Set 10 | rognan
# Processing Record 30 of Set 10 | stornoway
# Processing Record 31 of Set 10 | martil
# Processing Record 32 of Set 10 | fort nelson
# Processing Record 33 of Set 10 | lubango
# Processing Record 34 of Set 10 | shakawe
# Processing Record 35 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 10 | khawhai
# Processing Record 37 of Set 10 | xuddur
# Processing Record 38 of Set 10 | lusambo
# Processing Record 39 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 40 of Set 10 | houma
# Processing Record 41 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 10 | khotiv
# Processing Record 43 of Set 10 | bubaque
# Processing Record 44 of Set 10 | bafia
# Processing Record 45 of Set 10 | uyuni
# Processing Record 46 of Set 10 | devarkonda
# Processing Record 47 of Set 10 | henties bay
# Processing Record 48 of Set 10 | backa palanka
# Processing Record 49 of Set 10 | kapit
# Processing Record 50 of Set 10 | muniz freire
# Processing Record 1 of Set 11 | barletta
# Processing Record 2 of Set 11 | changzhou
# Processing Record 3 of Set 11 | beirut
# Processing Record 4 of Set 11 | hadgaon
# Processing Record 5 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 11 | nabire
# Processing Record 7 of Set 11 | thinadhoo
# Processing Record 8 of Set 11 | todos santos
# Processing Record 9 of Set 11 | ternate
# Processing Record 10 of Set 11 | kundiawa
# Processing Record 11 of Set 11 | umm lajj
# Processing Record 12 of Set 11 | pontes e lacerda
# Processing Record 13 of Set 11 | esmeraldas
# Processing Record 14 of Set 11 | narsaq
# Processing Record 15 of Set 11 | lontzen
# Processing Record 16 of Set 11 | strezhevoy
# Processing Record 17 of Set 11 | kabalo
# Processing Record 18 of Set 11 | batagay-alyta
# Processing Record 19 of Set 11 | aklavik
# Processing Record 20 of Set 11 | paamiut
# Processing Record 21 of Set 11 | aitape
# Processing Record 22 of Set 11 | sorong
# Processing Record 23 of Set 11 | broken hill
# Processing Record 24 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 11 | samana
# Processing Record 26 of Set 11 | tohana
# Processing Record 27 of Set 11 | norrkoping
# Processing Record 28 of Set 11 | denpasar
# Processing Record 29 of Set 11 | ha tinh
# Processing Record 30 of Set 11 | mercedes
# Processing Record 31 of Set 11 | khani
# Processing Record 32 of Set 11 | mocuba
# Processing Record 33 of Set 11 | rawlins
# Processing Record 34 of Set 11 | kot putli
# City not found. Skipping...
# Processing Record 35 of Set 11 | pringsewu
# Processing Record 36 of Set 11 | inhambane
# Processing Record 37 of Set 11 | angoche
# Processing Record 38 of Set 11 | santa isabel do rio negro
# Processing Record 39 of Set 11 | dawlatabad
# Processing Record 40 of Set 11 | haapu
# City not found. Skipping...
# Processing Record 41 of Set 11 | erdenet
# Processing Record 42 of Set 11 | alyangula
# Processing Record 43 of Set 11 | alice springs
# Processing Record 44 of Set 11 | crixas
# Processing Record 45 of Set 11 | mpika
# Processing Record 46 of Set 11 | monte cristi
# City not found. Skipping...
# Processing Record 47 of Set 11 | nenjiang
# Processing Record 48 of Set 11 | delta del tigre
# Processing Record 49 of Set 11 | kaka
# Processing Record 50 of Set 11 | salair
# Processing Record 1 of Set 12 | varhaug
# Processing Record 2 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 12 | bosaso
# Processing Record 4 of Set 12 | lata
# Processing Record 5 of Set 12 | shitkino
# Processing Record 6 of Set 12 | juneau
# Processing Record 7 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 8 of Set 12 | fukuchiyama
# Processing Record 9 of Set 12 | barabai
# Processing Record 10 of Set 12 | rocha
# Processing Record 11 of Set 12 | saldanha
# Processing Record 12 of Set 12 | faya
# Processing Record 13 of Set 12 | along
# Processing Record 14 of Set 12 | lotofaga
# Processing Record 15 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 12 | marzuq
# Processing Record 17 of Set 12 | mackay
# Processing Record 18 of Set 12 | nalut
# Processing Record 19 of Set 12 | bazaliya
# Processing Record 20 of Set 12 | dukat
# Processing Record 21 of Set 12 | podyuga
# Processing Record 22 of Set 12 | caravelas
# Processing Record 23 of Set 12 | christchurch
# Processing Record 24 of Set 12 | vestmannaeyjar
# Processing Record 25 of Set 12 | lazaro cardenas
# Processing Record 26 of Set 12 | ariquemes
# Processing Record 27 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 28 of Set 12 | zyryanka
# Processing Record 29 of Set 12 | labuhan
# Processing Record 30 of Set 12 | oyem
# Processing Record 31 of Set 12 | piet retief
# Processing Record 32 of Set 12 | batagay
# Processing Record 33 of Set 12 | ngaoundere
# Processing Record 34 of Set 12 | keti bandar
# Processing Record 35 of Set 12 | trelaze
# Processing Record 36 of Set 12 | devils lake
# Processing Record 37 of Set 12 | yining
# Processing Record 38 of Set 12 | clarence town
# Processing Record 39 of Set 12 | adre
# Processing Record 40 of Set 12 | san policarpo
# Processing Record 41 of Set 12 | porto walter
# Processing Record 42 of Set 12 | mogocha
# Processing Record 43 of Set 12 | kuusamo
# Processing Record 44 of Set 12 | srivardhan
# Processing Record 45 of Set 12 | custodia
# Processing Record 46 of Set 12 | inuvik
# Processing Record 47 of Set 12 | muros
# Processing Record 48 of Set 12 | presidencia roque saenz pena
# Processing Record 49 of Set 12 | west bay
# Processing Record 50 of Set 12 | medina
# Processing Record 1 of Set 13 | tangjiazhuang
# Processing Record 2 of Set 13 | mutoko
# Processing Record 3 of Set 13 | ibiruba
# Processing Record 4 of Set 13 | taltal
# Processing Record 5 of Set 13 | launceston
# Processing Record 6 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 7 of Set 13 | sistranda
# Processing Record 8 of Set 13 | turukhansk
# Processing Record 9 of Set 13 | samarai
# Processing Record 10 of Set 13 | srandakan
# Processing Record 11 of Set 13 | sobolevo
# Processing Record 12 of Set 13 | cerrito
# Processing Record 13 of Set 13 | melfi
# Processing Record 14 of Set 13 | sheridan
# Processing Record 15 of Set 13 | kokoda
# Processing Record 16 of Set 13 | carauari
# Processing Record 17 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 13 | great falls
# Processing Record 19 of Set 13 | rio rancho
# Processing Record 20 of Set 13 | santiago del estero
# Processing Record 21 of Set 13 | terney
# Processing Record 22 of Set 13 | praya
# Processing Record 23 of Set 13 | vung tau
# Processing Record 24 of Set 13 | alice
# Processing Record 25 of Set 13 | auch
# Processing Record 26 of Set 13 | camacha
# Processing Record 27 of Set 13 | kulhudhuffushi
# Processing Record 28 of Set 13 | methoni
# Processing Record 29 of Set 13 | leh
# Processing Record 30 of Set 13 | san ramon
# Processing Record 31 of Set 13 | boden
# Processing Record 32 of Set 13 | puerto madero
# Processing Record 33 of Set 13 | ambilobe
# Processing Record 34 of Set 13 | camopi
# Processing Record 35 of Set 13 | mackenzie
# Processing Record 36 of Set 13 | oriximina
# Processing Record 37 of Set 13 | pinega
# Processing Record 38 of Set 13 | waipawa
# Processing Record 39 of Set 13 | skelleftea
# Processing Record 40 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 13 | victoria point
# Processing Record 42 of Set 13 | eydhafushi
# Processing Record 43 of Set 13 | daru
# Processing Record 44 of Set 13 | mbanza-ngungu
# Processing Record 45 of Set 13 | lasa
# Processing Record 46 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 13 | haines junction
# Processing Record 48 of Set 13 | wampusirpi
# City not found. Skipping...
# Processing Record 49 of Set 13 | yaan
# Processing Record 50 of Set 13 | kindu
# Processing Record 1 of Set 14 | mahenge
# Processing Record 2 of Set 14 | saint-pierre
# Processing Record 3 of Set 14 | yavaros
# Processing Record 4 of Set 14 | kununurra
# Processing Record 5 of Set 14 | rock sound
# Processing Record 6 of Set 14 | yovon
# Processing Record 7 of Set 14 | vallenar
# Processing Record 8 of Set 14 | jacareacanga
# Processing Record 9 of Set 14 | buin
# Processing Record 10 of Set 14 | buritizeiro
# Processing Record 11 of Set 14 | ambovombe
# Processing Record 12 of Set 14 | miguel auza
# Processing Record 13 of Set 14 | black river
# Processing Record 14 of Set 14 | kaeo
# Processing Record 15 of Set 14 | sulangan
# Processing Record 16 of Set 14 | quixada
# Processing Record 17 of Set 14 | phuket
# Processing Record 18 of Set 14 | trinidad
# Processing Record 19 of Set 14 | merauke
# Processing Record 20 of Set 14 | hohhot
# Processing Record 21 of Set 14 | nueva gerona
# Processing Record 22 of Set 14 | flin flon
# Processing Record 23 of Set 14 | sabang
# Processing Record 24 of Set 14 | mayo
# Processing Record 25 of Set 14 | north bend
# Processing Record 26 of Set 14 | zhigansk
# Processing Record 27 of Set 14 | tateyama
# Processing Record 28 of Set 14 | shiyan
# Processing Record 29 of Set 14 | iskateley
# Processing Record 30 of Set 14 | vila nova de milfontes
# Processing Record 31 of Set 14 | olot
# Processing Record 32 of Set 14 | cairns
# Processing Record 33 of Set 14 | griffin
# Processing Record 34 of Set 14 | smidovich
# Processing Record 35 of Set 14 | port augusta
# Processing Record 36 of Set 14 | mogadouro
# Processing Record 37 of Set 14 | aguada de pasajeros
# Processing Record 38 of Set 14 | bonfim
# Processing Record 39 of Set 14 | kearney
# Processing Record 40 of Set 14 | port blair
# Processing Record 41 of Set 14 | sokoto
# Processing Record 42 of Set 14 | karamken
# City not found. Skipping...
# Processing Record 43 of Set 14 | caala
# Processing Record 44 of Set 14 | bartow
# Processing Record 45 of Set 14 | mianwali
# Processing Record 46 of Set 14 | marystown
# Processing Record 47 of Set 14 | cassilandia
# Processing Record 48 of Set 14 | egvekinot
# Processing Record 49 of Set 14 | valea nucarilor
# Processing Record 50 of Set 14 | martapura
# Processing Record 1 of Set 15 | orzhytsya
# Processing Record 2 of Set 15 | klamath falls
# Processing Record 3 of Set 15 | imbituba
# Processing Record 4 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 5 of Set 15 | saurimo
# Processing Record 6 of Set 15 | do gonbadan
# Processing Record 7 of Set 15 | novocheremshansk
# Processing Record 8 of Set 15 | kawalu
# Processing Record 9 of Set 15 | lamas
# Processing Record 10 of Set 15 | palu
# Processing Record 11 of Set 15 | missoula
# Processing Record 12 of Set 15 | warsaw
# Processing Record 13 of Set 15 | corning
# Processing Record 14 of Set 15 | firovo
# Processing Record 15 of Set 15 | kanniyakumari
# Processing Record 16 of Set 15 | liverpool
# Processing Record 17 of Set 15 | trairi
# Processing Record 18 of Set 15 | rivne
# Processing Record 19 of Set 15 | mandalgovi
# Processing Record 20 of Set 15 | belison
# Processing Record 21 of Set 15 | romny
# Processing Record 22 of Set 15 | bedele
# Processing Record 23 of Set 15 | idaho falls
# Processing Record 24 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 15 | susanville
# Processing Record 26 of Set 15 | veinticinco de mayo
# Processing Record 27 of Set 15 | khor
# Processing Record 28 of Set 15 | sao geraldo do araguaia
# Processing Record 29 of Set 15 | kahului
# Processing Record 30 of Set 15 | beloha
# Processing Record 31 of Set 15 | adamovka
# Processing Record 32 of Set 15 | lingao
# Processing Record 33 of Set 15 | muswellbrook
# Processing Record 34 of Set 15 | sigli
# Processing Record 35 of Set 15 | gazanjyk
# Processing Record 36 of Set 15 | sangar
# Processing Record 37 of Set 15 | puerto montt
# Processing Record 38 of Set 15 | hami
# Processing Record 39 of Set 15 | vao
# Processing Record 40 of Set 15 | brownwood
# Processing Record 41 of Set 15 | tarauaca
# Processing Record 42 of Set 15 | seymchan
# Processing Record 43 of Set 15 | novyy urengoy
# Processing Record 44 of Set 15 | baoying
# Processing Record 45 of Set 15 | tutoia
# Processing Record 46 of Set 15 | saint-augustin
# Processing Record 47 of Set 15 | valente
# Processing Record 48 of Set 15 | manokwari
# Processing Record 49 of Set 15 | pulivendla
# Processing Record 50 of Set 15 | lagunas
# Processing Record 1 of Set 16 | quang ngai
# Processing Record 2 of Set 16 | uhlove
# Processing Record 3 of Set 16 | takoradi
# Processing Record 4 of Set 16 | madang
# Processing Record 5 of Set 16 | yarada
# Processing Record 6 of Set 16 | lufilufi
# Processing Record 7 of Set 16 | pozo colorado
# Processing Record 8 of Set 16 | meulaboh
# Processing Record 9 of Set 16 | summerland
# Processing Record 10 of Set 16 | alenquer
# Processing Record 11 of Set 16 | venado tuerto
# Processing Record 12 of Set 16 | poso
# Processing Record 13 of Set 16 | calvinia
# Processing Record 14 of Set 16 | manta
# Processing Record 15 of Set 16 | maymyo
# Processing Record 16 of Set 16 | wuhu
# Processing Record 17 of Set 16 | bay roberts
# Processing Record 18 of Set 16 | waddan
# Processing Record 19 of Set 16 | pemba
# Processing Record 20 of Set 16 | taiyuan
# Processing Record 21 of Set 16 | sterling
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hermanus      ZA -34.4187   19.2345     57.79        76         100
# 1  Port Alfred      ZA -33.5906   26.8910     62.44        82          89
# 2        Kapaa      US  22.0752 -159.3190     82.38        72          20
# 3    Jamestown      US  42.0970  -79.2353     77.05        44           0
# 4       Bethel      US  41.3712  -73.4140     88.81        44           0
# 5      Ushuaia      AR -54.8000  -68.3000     38.82        87          75
# 6     Krasnoye      UA  49.9145   24.6134     58.35        87          33
# 7       Barrow      US  71.2906 -156.7887     44.62        93         100
# 8      Talnakh      RU  69.4865   88.3972     45.21        69          93
# 9       Cuamba      MZ -14.8031   36.5372     69.12        43          51
#
#    Wind Speed Current Description
# 0       13.44     overcast clouds
# 1        6.44     overcast clouds
# 2       16.11          few clouds
# 3       11.50           clear sky
# 4        8.05           clear sky
# 5        4.61       broken clouds
# 6        4.94    scattered clouds
# 7       21.85                mist
# 8        3.87     overcast clouds
# 9        2.75       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
